# %%
import sqlite3
import requests
#connection = sqlite3.connect("historical_data.db")

# %%
#cursor = connection.cursor()

# %%
#sql_file = open("../zerodha_historical_data.sql")

# %%
api_key= "pk_d7c347c3a36441c8a43f5af916ebf373"

# %%
response = requests.get(f"https://cloud.iexapis.com/stable/ref-data/isin?token={api_key}&isin=INE486A01013")

# %%
response.raise_for_status()

# %%
response.json()
# Out:
# [{'symbol': 'EQCESC-IG', 'region': 'IN', 'exchange': 'INMCX', 'iexId': None},
#  {'symbol': '500084-IB', 'region': 'IN', 'exchange': 'BOM', 'iexId': None},
#  {'symbol': 'EQCESC-IS', 'region': 'IN', 'exchange': 'NSE', 'iexId': None}]

# %%
response = requests.get(f"https://cloud.iexapis.com/stable/stock/500084-IB/quote?token=pk_d7c347c3a36441c8a43f5af916ebf373")

# %%
api_key="Tpk_4db7d5e62cbd4bd1a4cf3a11e72fd1a4"

# %%
response = requests.get(f"https://sandbox.iexapis.com/stable/ref-data/isin?token={api_key}&isin=INE486A01013")

# %%
response.json()
# Out:
# [{'symbol': 'EQCESC-IG', 'region': 'IN', 'exchange': 'INMCX', 'iexId': None},
#  {'symbol': '500084-IB', 'region': 'IN', 'exchange': 'BOM', 'iexId': None},
#  {'symbol': 'EQCESC-IS', 'region': 'IN', 'exchange': 'NSE', 'iexId': None}]

# %%
response
# Out:
# <Response [200]>

# %%
response = requests.get(f"https://cloud.iexapis.com/stable/stock/500084-IB/quote?token=pk_d7c347c3a36441c8a43f5af916ebf373")

# %%
response.raise_for_status()
/stock/twtr/chart/5y

# %%
response = requests.get(f"https://cloud.iexapis.com/stable/stock/500084-IB/chart/5y?token=pk_d7c347c3a36441c8a43f5af916ebf373")

# %%
response.json()
# Out:
# [{'close': 363.397,
#   'high': 366.4477,
#   'low': 353.9217,
#   'open': 357.6185,
#   'symbol': '500084-IB',
#   'volume': 32556.85355244079,
#   'id': 'HISTORICAL_PRICES',
#   'key': '500084-IB',
#   'subkey': '',
#   'date': '2016-04-18',
#   'updated': 1611281823000,
#   'changeOverTime': 0,
#   'marketChangeOverTime': 0,
#   'uOpen': 498.2,
#   'uClose': 506.25,
#   'uHigh': 510.5,
#   'uLow': 493.05,
#   'uVolume': 23370,
#   'fOpen': 309.653,
#   'fClose': 314.6565,
#   'fHigh': 317.298,
#   'fLow': 306.4521,
#   'fVolume': 32556.85355244079,
#   'label': 'Apr 18, 16',
#   'change': 0,
#   'changePercent': 0},
#  {'close': 377.5022,
#   'high': 384.6804,
#   'low': 363.9354,
#   'open': 365.371,
#   'symbol': '500084-IB',
#   'volume': 69313.91735137747,
#   'id': 'HISTORICAL_PRICES',
#   'key': '500084-IB',
#   'subkey': '',
#   'date': '2016-04-20',
#   'updated': 1611281878000,
#   'changeOverTime': 0.038814849874930245,
#   'marketChangeOverTime': 0.038814849874930245,
# ...
