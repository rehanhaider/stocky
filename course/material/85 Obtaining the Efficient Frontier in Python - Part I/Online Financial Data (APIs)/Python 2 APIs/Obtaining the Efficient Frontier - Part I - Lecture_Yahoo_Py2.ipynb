# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
assets = ['PG', '^GSPC']
pf_data = pd.DataFrame()

for a in assets:
    pf_data[a] = wb.DataReader(a, data_source = 'yahoo', start = '2010-1-1')['Adj Close']

# %%
pf_data.tail()
# Out:
#                    PG        ^GSPC
# Date
# 2019-01-29  93.540001  2640.000000
# 2019-01-30  94.519997  2681.050049
# 2019-01-31  96.470001  2704.100098
# 2019-02-01  97.470001  2706.530029
# 2019-02-05  97.699997  2733.699951

# %%
(pf_data / pf_data.iloc[0] * 100).plot(figsize=(10, 5))

# %%
log_returns = np.log(pf_data / pf_data.shift(1))

# %%
log_returns.mean() * 250
# Out:
# PG       0.083546
# ^GSPC    0.096325
# dtype: float64

# %%
log_returns.cov() * 250
# Out:
#              PG     ^GSPC
# PG     0.021374  0.011684
# ^GSPC  0.011684  0.022498

# %%
log_returns.corr()
# Out:
#              PG     ^GSPC
# PG     1.000000  0.532796
# ^GSPC  0.532796  1.000000

# %%
num_assets = len(assets)

# %%
num_assets
# Out:
# 2

# %%
arr = np.random.random(2)
arr
# Out:
# array([ 0.57064007,  0.82210757])

# %%
arr[0] + arr[1]
# Out:
# 1.3927476358271529

# %%
weights = np.random.random(num_assets)
weights /= np.sum(weights)
weights
# Out:
# array([ 0.10020429,  0.89979571])

# %%
weights[0] + weights[1]
# Out:
# 1.0
